# %% [markdown]
# ## Jupyter Lab Shortcut

# %% [markdown]
# - **ESC** : masuk ke Command Mode
# - **ENTER** : masuk ke Cell Mode
# - **ESC** + **A**  : Menambahkan cell ke atas
# - **ESC** + **B** : Menambahkan cell ke bawah
# - **ESC** + **D D** : Delete cell terpilih
# - **CTRL** + **B** : Show hide left panel
# - **SHIFT** + **M** : Merge selected cell
# - **CTRL** + **SHIFT** + **–** : Split cell from cursor position
# - **SHIFT** + **DOWN** : Select multiple cell (downward direction)
# - **SHIFT** + **UP** : Select multiple cell (Upward direction)
# - **CTRL** + **/** : Commenting or uncommenting

# %% [markdown]
# ## Access Multiple Environment From Jupyter lab (base)
# - `nb_conda_kernels` in the environment with Jupyter. \
# ```conda install nb_conda```
#
# - `ipykernel` in the Python environment you want to access. \
# ```conda install ipykernel```

# %%
import sys

# %%
sys.path
# Out:
# ['c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\python38.zip',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\DLLs',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM',
#  '',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib\\site-packages',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib\\site-packages\\win32',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib\\site-packages\\win32\\lib',
#  'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# ### OpenCV - Part 1
#
# - Access Individual pixel
# - Read, Show, & Save Image
# - Read, Show, & Save Video
# - Capture photo from camera
# - Capture video from camera
#
# ___

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.13.0'

# %%
cv2.__file__
# Out:
# 'c:\\Users\\Administrator\\anaconda3\\envs\\TugasM\\lib\\site-packages\\cv2\\__init__.py'

# %% [markdown]
# ### Read Image

# %%
img = cv2.imread("lena.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Image Matrix

# %%
img.shape
# Out:
# (344, 354, 3)

# %%
type(img.shape)
# Out:
# tuple

# %%
# tuple unpacking
h, w, c = img.shape

# %%
h, w, c
# Out:
# (344, 354, 3)

# %%
h*w
# Out:
# 121776

# %%
img.nbytes #in Bytes
# Out:
# 365328

# %%
img.nbytes/1024 #in kB
# Out:
# 356.765625

# %%
import os

# %%
os.path.getsize("lena.jpg")/1024 # jpeg compresed file (in kB)
# Out:
# 32.79296875

# %%
img.ndim #3D
# Out:
# 3

# %%
img.min()
# Out:
# 0

# %%
img.max()
# Out:
# 255

# %%
img.size # n pixel
# Out:
# 365328

# %%
h*w*c # n pixel
# Out:
# 365328

# %% [markdown]
# ### Access Image Channel

# %%
img[:, :, 0].shape # layer 0 (Blue)
# Out:
# (344, 354)

# %%
img[:, :, 1].shape # layer 1 (Green)
# Out:
# (344, 354)

# %%
img[:, :, 2].shape # layer 2 (Red)
# Out:
# (344, 354)

# %% [markdown]
# ### Access Individual pixel

# %%
img[0, 0]
# Out:
# array([ 82,  73, 183], dtype=uint8)

# %%
(B, G, R) = img[200, 200]

print("R=%d, G=%d, B=%d" % (R, G, B))
# Out:
# R=221, G=118, B=119

# %% [markdown]
# ### Read & Display Image

# %%
import cv2

# %%
# read image
img = cv2.imread('lena.jpg')

# %% [markdown]
# - Menggunkan GUI OpenCV

# %%
# show image
cv2.imshow('myapp',img)
cv2.waitKey(0) #display the window infinitely until any keypress
cv2.destroyAllWindows()

# %%
chr(97)
# Out:
# 'a'

# %%
cv2.destroyAllWindows()

# %%
cv2.imshow('lena.jpg',img)
res = cv2.waitKey(6000) # display the window for 6000 ms (6 s), 
                        # if any keypress detected before 6 s, 
                        # the window will be closed. 
print(res)
cv2.destroyAllWindows()
# Out:
# 113

# %%
# show image
cv2.imshow('lena.jpg',img)
res = cv2.waitKey(4000)
print('You pressed : %s' % chr(res) if res >=0 and res <= 127 else '<unknown>')
cv2.destroyAllWindows()
# Out:
# You pressed : q

# %% [markdown]
# - Menggunakan Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
img_rgb = img[:,:,::-1] # numpy reverse matrix (BGR to RGB)
plt.imshow(img_rgb)

# %%
img_red = img[:,:, 2]

plt.imshow(img_red, cmap='gray')

# %%
img_green = img[:,:, 1]

plt.imshow(img_green, cmap='gray')

# %%
img_blue = img[:,:, 0]

plt.imshow(img_blue, cmap='gray')

# %% [markdown]
# ___
# #### Numpy Slicing [start:stop:step]

# %%
import numpy as np

# %%
a = np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
a[0:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
a[0:5:2]
# Out:
# array([0, 2, 4])

# %% [markdown]
# - Numpy Slicing Notation
#
# `a[start:]` \
# `a[:stop]` \
# `a[start:stop]` \
# `a[start:stop:step]`
#
#
# - Negative step (reverse array)
#
# `a[::-1]`    # all items in the array, reversed \
# `a[1::-1]`   # the first two items, reversed \
# `a[:-3:-1]`  # the last two items, reversed \
# `a[-3::-1]`  # everything except the last two items, reversed

# %% [markdown]
# - jika step bernilai negatif, start > stop

# %%
a[::-1] # reverse dari [0, 1, 2, 3, 4]
# Out:
# array([4, 3, 2, 1, 0])

# %%
a[1::-1] # reverse, step -1, -> 1, 0
# Out:
# array([1, 0])

# %%
a[:-3:-1] # reverse, step -1, start 4, 3
# Out:
# array([4, 3])

# %% [markdown]
# ___

# %% [markdown]
# - Convert menggunakan `cv2.cvtColor`

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # convert BGR to RGB color
plt.imshow(img_rgb)

# %%
# task 2 GUI image using OpenCV GUI

# %%
# show image
img1= cv2.imread('lena.jpg')
img2= cv2.imread('myimage.jpg')
cv2.imshow('myapp 1',img1)
cv2.imshow('myapp 2',img2)
cv2.waitKey(0) #display the window infinitely until any keypress
cv2.destroyAllWindows()

# %% [markdown]
# ## Save Image

# %%
# show image
cv2.imwrite('saved_lena.jpg', img)
# Out:
# True

# %% [markdown]
# ### Play Video

# %%
# load video
cap = cv2.VideoCapture('video.mp4')

# iterate for each frame in video
while cap.isOpened():
    
    # get image on each frame
    ret, frame = cap.read()

    # show image
    cv2.imshow('Frame',frame)

    # wait 25ms per frame and close using 'q' 
    if cv2.waitKey(25) == ord('q'):
          break

#close video
cap.release()
#close window
cv2.destroyAllWindows()

# %%
#close video
cap.release()
#close window
cv2.destroyAllWindows()

# %%
# load video
cap = cv2.VideoCapture('video.mp4')
           
# iterate for each frame in video
while cap.isOpened():
    
    # get image on each frame
    ret, frame = cap.read()
    if ret == True:
        
        # show image
        cv2.imshow('Frame',frame)
        
        # wait 25ms per frame and close using 'q' 
        if cv2.waitKey(25) == ord('q'):
              break
        if cv2.waitKey(25) == ord('s'):
            cv2.imwrite("foto_from_video.jpg", frame)
            print("foto captured!")
    else: 
        break

#close video
cap.release()
#close window
cv2.destroyAllWindows()
# Out:
# foto captured!

# %% [markdown]
# ### Capture Photo

# %%
cap = cv2.VideoCapture(1)
ret, frame = cap.read()

if ret :
    cv2.imwrite("my_photo_2.jpg", frame)
else :
    print("can't save photo")
    
#close video
cap.release()
# Out:
# can't save photo

# %% [markdown]
# ### Capture Video

# %%
cap = cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 320)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 240)

# Define the codec and create VideoWriter object
# fourcc is a 4-byte code used to specify the video codec
fourcc = cv2.VideoWriter_fourcc(*'MP4V') # fourcc for .avi

out = cv2.VideoWriter('output_2.mp4',fourcc, 20, (320,240)) # name, fourcc, fps, size

cv2.VideoWriter
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        key = cv2.waitKey(1) 
        if key == ord('q'):
            break
        if key == ord('s'):
            cv2.imwrite("foto_from_video.jpg", frame)
            print("foto captured!")
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# foto captured!

# %%
cap.release()
out.release()
cv2.destroyAllWindows()
